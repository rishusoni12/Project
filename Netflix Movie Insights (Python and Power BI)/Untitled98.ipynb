# %%
Objective:
Netflix is known for its work in data science, that understand customer behavior and patterns.
Suppose you are working in a data-driven job role, and you have a dataset of more than 9,000 movies. 
You need to solve the following questions to help the company make informed business decisions accordingly.

# %%
#import Library
import pandas as pd
import seaborn as  sns 
import matplotlib.pyplot as plt

# %%
#Data Fathering

# %%
df = pd.read_csv("mymoviedb (3).csv",lineterminator='\n')

# %%
#Exploratory Data Analysis (EDA)

# %%
df
# Out:
#      Release_Date                                 Title  \
# 0      2021-12-15               Spider-Man: No Way Home
# 1      2022-03-01                            The Batman
# 2      2022-02-25                               No Exit
# 3      2021-11-24                               Encanto
# 4      2021-12-22                        The King's Man
# ...           ...                                   ...
# 9822   1973-10-15                              Badlands
# 9823   2020-10-01                      Violent Delights
# 9824   2016-05-06                          The Offering
# 9825   2021-03-31  The United States vs. Billie Holiday
# 9826   1984-09-23                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# ...

# %%
df.shape
# Out:
# (9827, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9827 entries, 0 to 9826
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Release_Date       9827 non-null   object
#  1   Title              9827 non-null   object
#  2   Overview           9827 non-null   object
#  3   Popularity         9827 non-null   float64
#  4   Vote_Count         9827 non-null   int64
#  5   Vote_Average       9827 non-null   float64
#  6   Original_Language  9827 non-null   object
#  7   Genre              9827 non-null   object
#  8   Poster_Url         9827 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 691.1+ KB

# %%
df.describe().T
# Out:
#                count         mean          std     min       25%      50%  \
# Popularity    9827.0    40.326088   108.873998  13.354   16.1285   21.199
# Vote_Count    9827.0  1392.805536  2611.206907   0.000  146.0000  444.000
# Vote_Average  9827.0     6.439534     1.129759   0.000    5.9000    6.500
#
#                     75%        max
# Popularity      35.1915   5083.954
# Vote_Count    1376.0000  31077.000
# Vote_Average     7.1000     10.000

# %%
df.head()
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
df.sample(5)
# Out:
#      Release_Date                                    Title  \
# 7683   2007-02-09                         Music and Lyrics
# 3915   2006-06-20                               The Wailer
# 1466   2017-07-15                    No Game No Life: Zero
# 2817   1981-07-17                             Endless Love
# 9723   1982-03-13  Doraemon: Nobita and the Haunts of Evil
#
#                                                Overview  Popularity  \
# 7683  A washed-up '80s pop star gets a chance at a c...      15.698
# 3915  On their way to Mexico, six students are stran...      24.889
# 1466  In ancient Disboard, Riku is an angry, young w...      51.181
# 2817  Two young kids fall in love with each other. B...      31.628
# 9723  Nothing is impossible for Doraemon's magic poc...      13.444
#
#       Vote_Count  Vote_Average Original_Language  \
# 7683        1394           6.4                en
# 3915          51           6.6                es
# ...

# %%
df.isnull().sum()
# Out:
# Release_Date         0
# Title                0
# Overview             0
# Popularity           0
# Vote_Count           0
# Vote_Average         0
# Original_Language    0
# Genre                0
# Poster_Url           0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Release_Date         datetime64[ns]
# Title                        object
# Overview                     object
# Popularity                  float64
# Vote_Count                    int64
# Vote_Average                float64
# Original_Language            object
# Genre                        object
# Poster_Url                   object
# dtype: object

# %%
df["Release_Date"] = pd.to_datetime(df["Release_Date"])

# %%
df.columns
# Out:
# Index(['Release_Date', 'Title', 'Overview', 'Popularity', 'Vote_Count',
#        'Vote_Average', 'Original_Language', 'Genre'],
#       dtype='object')

# %%
df.drop(["Poster_Url"], axis=1, inplace=True)

# %%
df[1:5] #Slicing
# Out:
#   Release_Date           Title  \
# 1   2022-03-01      The Batman
# 2   2022-02-25         No Exit
# 3   2021-11-24         Encanto
# 4   2021-12-22  The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre
# 1           8.1                en            Crime, Mystery, Thriller
# 2           6.3                en                            Thriller
# 3           7.7                en  Animation, Comedy, Family, Fantasy
# 4           7.0                en    Action, Adventure, Thriller, War

# %%
df["Popularity"].min()
# Out:
# 13.354

# %%
df["Popularity"].max()
# Out:
# 5083.954

# %%
df["Popularity"].median()
# Out:
# 21.199

# %%
df["Popularity"].mean()
# Out:
# 40.32608822631525

# %%
df["Popularity"].skew()
# Out:
# 21.901432583478837

# %%
#Data Visulization

# %%
plt.figure(figsize=(15,10))
sns.boxplot(df["Popularity"])
plt.show()

# %%
df["Vote_Count"].mean()
# Out:
# 1392.8055357688002

# %%
df["Vote_Count"].median()
# Out:
# 444.0

# %%
plt.figure(figsize=(15,10))
sns.boxplot(df["Vote_Count"])
plt.show()

# %%
df["Vote_Average"].mean()
# Out:
# 6.439533937112038

# %%
df["Vote_Average"].median()
# Out:
# 6.5

# %%
df["Vote_Average"].max()
# Out:
# 10.0

# %%
sns.histplot(df["Vote_Average"], kde=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df["Genre"].value_counts()
# Out:
# Genre
# Drama                                            466
# Comedy                                           403
# Drama, Romance                                   248
# Horror                                           238
# Horror, Thriller                                 199
#                                                 ...
# Drama, Horror, Thriller, Science Fiction           1
# Action, Science Fiction, Animation, Adventure      1
# Comedy, Fantasy, Horror, Science Fiction           1
# Drama, Science Fiction, Animation                  1
# War, Drama, Science Fiction                        1
# Name: count, Length: 2337, dtype: int64

# %%
a = df["Genre"].value_counts().head(5)
a
plt.pie(a, autopct="%1.1f%%", labels=a.index)  #a.index is for name  genre 
plt.show()

# %%
df.groupby("Genre")["Vote_Count"].sum()
# Out:
# Genre
# Action                                          31420
# Action, Adventure                               27944
# Action, Adventure, Animation                     1002
# Action, Adventure, Animation, Comedy              293
# Action, Adventure, Animation, Comedy, Family     6305
#                                                 ...
# Western, Drama, Mystery                           798
# Western, History                                  179
# Western, Horror                                  1620
# Western, Mystery, Thriller, Drama                 834
# Western, Thriller                                1202
# Name: Vote_Count, Length: 2337, dtype: int64

# %%
a = df.groupby("Genre")["Vote_Count"].sum().sort_values(ascending=False).head(10)
a
plt.figure(figsize=(10,10))
sns.barplot(a)
plt.show()

# %%
a = df.groupby("Genre")["Popularity"].sum()
a = df.sort_values("Popularity", ascending=False)
a.head(5)
# Out:
#   Release_Date                    Title  \
# 0   2021-12-15  Spider-Man: No Way Home
# 1   2022-03-01               The Batman
# 2   2022-02-25                  No Exit
# 3   2021-11-24                  Encanto
# 4   2021-12-22           The King's Man
#
#                                             Overview  Popularity  Vote_Count  \
# 0  Peter Parker is unmasked and no longer able to...    5083.954        8940
# 1  In his second year of fighting crime, Batman u...    3827.658        1151
# 2  Stranded at a rest stop in the mountains durin...    2618.087         122
# 3  The tale of an extraordinary family, the Madri...    2402.201        5076
# 4  As a collection of history's worst tyrants and...    1895.511        1793
#
#    Vote_Average Original_Language                               Genre  \
# 0           8.3                en  Action, Adventure, Science Fiction
# 1           8.1                en            Crime, Mystery, Thriller
# ...

# %%
a = df.groupby("Genre")[["Popularity","Vote_Count"]].sum().sort_values(by=["Popularity","Vote_Count"],ascending=False).head(10)
a
# Out:
#                                     Popularity  Vote_Count
# Genre
# Drama                                12460.914      491667
# Comedy                               12350.057      417198
# Horror                               12177.826      155140
# Action, Adventure, Science Fiction    8571.728      302852
# Thriller                              8546.185       42729
# Horror, Thriller                      6843.343      205511
# Action, Thriller                      6607.258      165870
# Drama, Romance                        6530.151      285337
# Action, Crime, Thriller               6263.309       96435
# Comedy, Romance                       5689.336      246391

# %%
a = df.groupby("Genre")["Popularity"].sum().sort_values(ascending=False).head(5)
a 
plt.figure(figsize=(15,10))
sns.barplot(a)
plt.show()

# %%
df.groupby("Genre")["Vote_Average"].sum()
# Out:
# Genre
# Action                                          601.9
# Action, Adventure                               150.8
# Action, Adventure, Animation                     40.7
# Action, Adventure, Animation, Comedy              6.9
# Action, Adventure, Animation, Comedy, Family     19.9
#                                                 ...
# Western, Drama, Mystery                           7.4
# Western, History                                  6.3
# Western, Horror                                  12.7
# Western, Mystery, Thriller, Drama                 7.1
# Western, Thriller                                15.1
# Name: Vote_Average, Length: 2337, dtype: float64

# %%
a = df.groupby("Genre")["Vote_Average"].sum().sort_values(ascending=False).head(10)
a
plt.figure(figsize=(15,10))
sns.barplot(a)
plt.show()

# %%
df.sort_values(["Genre","Vote_Average"], ascending=[True, False])
# Out:
#      Release_Date             Title  \
# 3622   1994-12-22    Fist of Legend
# 2956   1973-08-17  Enter the Dragon
# 136    2021-05-06        Crazy Fist
# 3767   1971-10-03      The Big Boss
# 6954   2007-10-26        Crows Zero
# ...           ...               ...
# 5786   2015-10-23     Bone Tomahawk
# 8745   2014-08-25        Blood Moon
# 5709   2016-03-12         Brimstone
# 9652   1952-06-09         High Noon
# 5794   2021-10-01         Old Henry
#
#                                                Overview  Popularity  \
# 3622  Chen Zhen, a Chinese engineering student in Ky...      26.325
# 2956  A martial artist agrees to spy on a reclusive ...      30.520
# 136   After an opponent dies mid-match, a prominent ...     230.547
# 3767  Chen is a city boy who moves with his cousins ...      25.545
# 6954  The students of Suzuran High compete for the K...      16.780
# ...                                                 ...         ...
# ...

# %%
a = df.groupby("Genre")["Vote_Average"].sum()
a = df.sort_values("Vote_Average",ascending=False)
a
# Out:
#      Release_Date                                          Title  \
# 9391   2020-04-09                     Kung Fu Master Huo Yuanjia
# 7339   2018-06-08              Franco Escamilla: Por La Anécdota
# 667    2019-03-29  Demon Slayer: Kimetsu no Yaiba Sibling's Bond
# 2325   2021-06-17                              Impossible Things
# 7401   2020-10-30                                    My Sex Doll
# ...           ...                                            ...
# 4432   2022-03-09                                      Soy Libre
# 402    2022-06-08                        Jurassic World Dominion
# 322    2022-05-04    Doctor Strange in the Multiverse of Madness
# 6831   2020-11-26                      Jakarta, City of Dreamers
# 5378   2022-03-10                                    Radhe Shyam
#
#                                                Overview  Popularity  \
# 9391  The young and vigorous Huo Yuanjia was only fo...      13.745
# ...

# %%
df["Original_Language"].value_counts()
# Out:
# Original_Language
# en    7570
# ja     645
# es     339
# fr     292
# ko     170
# zh     129
# it     123
# cn     109
# ru      83
# de      82
# pt      37
# da      28
# no      26
# hi      26
# sv      23
# nl      21
# pl      17
# th      17
# id      15
# tr      15
# tl       8
# te       6
# el       5
# fi       5
# sr       5
# cs       4
# fa       3
# hu       3
# is       2
# ro       2
# uk       2
# ta       2
# ar       2
# he       2
# ca       1
# la       1
# nb       1
# bn       1
# ms       1
# lv       1
# eu       1
# ml       1
# et       1
# Name: count, dtype: int64

# %%
a=df["Original_Language"].value_counts().head(5)
a
sns.barplot(a)
plt.show()

# %%
a=df.groupby("Original_Language")["Genre"].count().sort_values(ascending=False).head(10)
a
sns.lineplot(a, sizes=10,marker="*")
plt.show()

# %%
df.groupby("Original_Language")["Popularity"].sum().sort_values(ascending=False)
# Out:
# Original_Language
# en    316120.935
# ja     26266.534
# es     12871.659
# fr      9613.040
# ko      5697.255
# zh      3872.526
# ru      3291.630
# it      3184.453
# cn      2522.345
# hi      2234.223
# de      2127.326
# pt      1274.990
# tr      1074.471
# th      1034.791
# pl       914.768
# no       715.402
# da       627.811
# nl       514.064
# sv       486.705
# id       400.493
# fi       195.207
# te       182.762
# tl       169.255
# ml       151.512
# sr        95.954
# el        82.548
# cs        66.806
# ro        60.359
# fa        57.683
# is        48.625
# hu        43.184
# uk        39.163
# ar        34.592
# ta        31.453
# he        29.487
# nb        22.410
# eu        21.859
# lv        21.540
# ms        18.416
# bn        18.059
# ca        17.214
# la        17.138
# et        13.822
# Name: Popularity, dtype: float64

# %%
a=df.groupby("Original_Language")["Popularity"].sum().sort_values(ascending=False).head(5)
a
plt.pie(a,autopct="%1.1f%%", labels=a.index)
plt.title("Original Language by Popularity")
plt.show()

sns.barplot(a)
plt.show()

sns.lineplot(a)
plt.show()

# %%
df.groupby("Original_Language")["Vote_Count"].sum().sort_values(ascending=False)
# Out:
# Original_Language
# en    12772821
# ja      209906
# fr      195047
# es      112822
# it       85948
# ko       78987
# de       43643
# cn       34272
# zh       29433
# ru       20270
# sv       15841
# pt       14462
# da       11876
# hi        9942
# pl        8811
# no        7720
# id        5831
# th        5432
# tr        5330
# nl        4090
# sr        2595
# el        2328
# ar        1403
# nb        1239
# fa        1216
# te        1149
# la         914
# cs         664
# hu         537
# fi         478
# eu         421
# is         412
# uk         374
# he         192
# ml         192
# ta         173
# ro         132
# tl          59
# et          55
# ms          55
# bn          18
# ca          10
# lv           0
# Name: Vote_Count, dtype: int64

# %%
a=df.groupby("Original_Language")["Vote_Count"].sum().sort_values(ascending=False).head(10)
a
sns.barplot(a)
plt.show()

sns.lineplot(a)
plt.show()

plt.figure(figsize=(5,8))
plt.pie(a,autopct="%1.1f%%", labels=a.index)
plt.show()

sns.kdeplot(a,shade=True)
plt.show()
# Out:
# C:\Users\soniv\AppData\Local\Temp\ipykernel_12220\2747595115.py:13: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(a,shade=True)

# %%
df.groupby("Original_Language")["Vote_Average"].sum().sort_values(ascending=False)
# Out:
# Original_Language
# en    48226.5
# ja     4501.6
# es     2229.3
# fr     1843.9
# ko     1152.7
# zh      869.0
# it      803.1
# cn      712.5
# ru      569.0
# de      551.8
# pt      239.6
# da      185.0
# hi      172.3
# no      167.2
# sv      161.5
# nl      133.0
# th      111.1
# pl      103.9
# tr       96.7
# id       83.0
# tl       34.6
# el       33.8
# te       32.1
# fi       31.1
# cs       29.2
# sr       28.5
# fa       22.7
# hu       22.0
# uk       15.3
# ar       14.9
# is       13.3
# ta       12.8
# ro       12.5
# he       12.4
# ms        7.7
# ml        7.2
# la        7.1
# et        7.0
# nb        6.7
# eu        6.4
# ca        6.0
# bn        5.3
# lv        0.0
# Name: Vote_Average, dtype: float64

# %%
a=df.groupby("Original_Language")["Vote_Average"].sum().sort_values(ascending=False).head(10)
a
sns.barplot(a)
plt.show()

sns.lineplot(a, marker="*")
plt.show()

# %%
df["Month"] = df["Release_Date"].dt.month

# %%
df["Year"] = df["Release_Date"].dt.year

# %%
a = df.groupby("Month")["Popularity"].sum().sort_values(ascending=False)
a
sns.barplot(a, palette="deep")
plt.show()

sns.lineplot(a, marker="*")
plt.show()
# Out:
# C:\Users\soniv\AppData\Local\Temp\ipykernel_11800\3519509960.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(a, palette="deep")
# C:\Users\soniv\AppData\Local\Temp\ipykernel_11800\3519509960.py:9: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(a)

# %%
a = df.groupby("Month")["Vote_Count"].sum().sort_values(ascending=False)
a
plt.figure(figsize=(10,5))
sns.barplot(a, palette="deep")
plt.show()

sns.lineplot(a)
plt.show()
# Out:
# C:\Users\soniv\AppData\Local\Temp\ipykernel_11800\1813516933.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(a, palette="deep")

# %%
a = df.groupby("Month")["Vote_Average"].sum().sort_values(ascending=False)
a
plt.figure(figsize=(10,5))
sns.barplot(a, palette="deep")
plt.show()

sns.lineplot(a)
plt.show()
# Out:
# C:\Users\soniv\AppData\Local\Temp\ipykernel_11800\2728828905.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(a, palette="deep")

# %%
df.groupby("Month")["Genre"].value_counts().head(5)
# Out:
# Month  Genre
# 1      Drama               34
#        Horror              25
#        Comedy              22
#        Horror, Thriller    19
#        Comedy, Romance     18
# Name: count, dtype: int64

# %%
a = df.groupby("Year")["Popularity"].sum().head(10).sort_values(ascending=False)
a
plt.figure(figsize=(10,5))
sns.barplot(a, palette="deep")
plt.show()

sns.lineplot(a)
plt.show()
# Out:
# C:\Users\soniv\AppData\Local\Temp\ipykernel_11800\1167920715.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(a, palette="deep")

# %%
a = df.groupby("Year")["Vote_Count"].sum().head(10).sort_values(ascending=False)
a
plt.figure(figsize=(10,5))
sns.barplot(a, palette="deep")
plt.show()

sns.lineplot(a)
plt.show()
# Out:
# C:\Users\soniv\AppData\Local\Temp\ipykernel_11800\4228818136.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(a, palette="deep")

# %%
a = df.groupby("Year")["Vote_Average"].sum().head(10).sort_values(ascending=False)
a
plt.figure(figsize=(10,5))
sns.barplot(a, palette="deep")
plt.show()

sns.lineplot(a)
plt.show()
# Out:
# C:\Users\soniv\AppData\Local\Temp\ipykernel_11800\654557717.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(a, palette="deep")

# %%
df.groupby("Year")["Original_Language"].value_counts().head(15).sort_values(ascending=False)
# Out:
# Year  Original_Language
# 1931  en                   4
# 1902  fr                   1
# 1920  de                   1
# 1921  en                   1
#       sv                   1
# 1922  de                   1
#       sv                   1
# 1925  ru                   1
# 1926  de                   1
#       en                   1
# 1927  de                   1
#       en                   1
# 1929  fr                   1
# 1930  en                   1
# 1931  de                   1
# Name: count, dtype: int64

# %%
a = df.groupby("Month")["Original_Language"].value_counts().head(50).sort_values(ascending=False)
a
# Out:
# Month  Original_Language
# 3      en                   637
# 2      en                   580
# 1      en                   494
# 3      ja                    90
# 2      ja                    34
# 3      es                    33
#        fr                    30
# 2      fr                    29
# 1      es                    28
#        ja                    26
# 2      es                    26
# 1      fr                    23
# 2      zh                    19
#        ko                    16
#        cn                    14
#        it                    14
#        de                    13
# 3      it                    12
# 1      it                    12
#        ko                    11
#        zh                    11
# 2      ru                    11
# 1      cn                    10
# 3      cn                     9
# 1      ru                     9
#        pt                     6
#        de                     5
# 2      sv                     4
# ...

# %%
Most Popular Genre

# %%
df.sort_values("Genre", ascending=True).head(50)
# Out:
#      Release_Date                                Title  \
# 8670   2005-03-12               Azumi 2: Death or Love
# 7590   1998-05-01                            Black Dog
# 288    2009-09-29                       Ninja Assassin
# 2624   2014-08-05                          Mercenaries
# 6289   2009-12-29                         The Marine 2
# 2555   1991-08-23             Showdown in Little Tokyo
# 9294   2006-05-02                    Second in Command
# 7734   1986-01-17                           Iron Eagle
# 6954   2007-10-26                           Crows Zero
# 7756   1985-11-01                         Death Wish 3
# 5257   1996-02-09                         Broken Arrow
# 4982   2017-08-04                           Savage Dog
# 5385   2020-06-15               Sniper: Assassin's End
# 297    2021-11-15              Never Back Down: Revolt
# 2436   2014-08-12             TEKKEN: Kazuya's Revenge
# 2417   2004-01-16                               Torque
# ...

# %%
df.drop(["Poster_Url"], axis=1, inplace=True)

# %%
Most Popular Title

# %%
df.groupby("Title")["Popularity"].sum().sort_values(ascending=False)
# Out:
# Title
# Spider-Man: No Way Home                 5083.954
# The Batman                              3827.658
# No Exit                                 2618.087
# Encanto                                 2402.201
# The King's Man                          1895.511
#                                           ...
# Badlands                                  13.357
# Violent Delights                          13.356
# The Offering                              13.355
# The United States vs. Billie Holiday      13.354
# Threads                                   13.354
# Name: Popularity, Length: 9513, dtype: float64

# %%
df.groupby("Title")["Vote_Count"].sum().sort_values(ascending=False)
# Out:
# Title
# Inception                            31077
# Interstellar                         27975
# The Avengers                         27038
# The Dark Knight                      26994
# Deadpool                             26390
#                                      ...
# Goyo: En Letra de Otro                   0
# Thor: Love and Thunder                   0
# The Girl From the Other Side             0
# Constantine: The House of Mystery        0
# Who Said Detox?                          0
# Name: Vote_Count, Length: 9513, dtype: int64

# %%
df.groupby("Title")["Vote_Average"].sum().sort_values(ascending=False)
# Out:
# Title
# Beauty and the Beast                           28.3
# Alice in Wonderland                            26.3
# Les Misérables                                 22.2
# King Kong                                      20.6
# The Kid                                        20.5
#                                                ...
# Apollo 10½:  A Space Age Childhood              0.0
# Doctor Strange in the Multiverse of Madness     0.0
# X                                               0.0
# Minions: The Rise of Gru                        0.0
# Cam Girls                                       0.0
# Name: Vote_Average, Length: 9513, dtype: float64

# %%
a = df[["Popularity","Vote_Count","Vote_Average"]]
b = a.corr()
b = b.round(3)
b
# Out:
#               Popularity  Vote_Count  Vote_Average
# Popularity         1.000       0.137         0.054
# Vote_Count         0.137       1.000         0.254
# Vote_Average       0.054       0.254         1.000

# %%
sns.heatmap(b, annote=True)
plt.show()

# %%
df.columns
# Out:
# Index(['Release_Date', 'Title', 'Overview', 'Popularity', 'Vote_Count',
#        'Vote_Average', 'Original_Language', 'Genre'],
#       dtype='object')

# %% [raw]
# what is the most frequent genre of movie released on Netflix

# %%
a=df["Genre"].value_counts().sort_values(ascending=False).head(10)
a
plt.figure(figsize=(15,10))
sns.barplot(a)
plt.title("Most Frequent genre release",size=15)
plt.show()

# %% [raw]
# which is highest vote is avg column

# %%
# Out:
# Genre   Vote_Average
# Action  5.9             8
#         6.3             8
#         6.4             7
#         6.5             7
#         5.1             6
# Name: count, dtype: int64

# %% [raw]
# what is highest got popularity what is Title it

# %%
a = df.groupby("Title")["Popularity"].sum().sort_values(ascending=False).head(5)
a
color = sns.color_palette("pastel")
plt.pie(a,autopct="%1.1f%%", labels=a.index, colors=color)
plt.show()

plt.figure(figsize=(10,5))
sns.barplot(a, palette="deep")
plt.show()
# Out:
# C:\Users\soniv\AppData\Local\Temp\ipykernel_11800\3573230944.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(a, palette="deep")

# %% [raw]
# what is highest got popularity what is genre it

# %%
a=df[["Title","Genre","Popularity"]].sort_values(by="Popularity",ascending=False).head(5)
a
# Out:
#                      Title                               Genre  Popularity
# 0  Spider-Man: No Way Home  Action, Adventure, Science Fiction    5083.954
# 1               The Batman            Crime, Mystery, Thriller    3827.658
# 2                  No Exit                            Thriller    2618.087
# 3                  Encanto  Animation, Comedy, Family, Fantasy    2402.201
# 4           The King's Man    Action, Adventure, Thriller, War    1895.511

# %%
a=df[["Genre","Popularity"]].head(5)
a
# Out:
#                                 Genre  Popularity
# 0  Action, Adventure, Science Fiction    5083.954
# 1            Crime, Mystery, Thriller    3827.658
# 2                            Thriller    2618.087
# 3  Animation, Comedy, Family, Fantasy    2402.201
# 4    Action, Adventure, Thriller, War    1895.511

# %%
a= df.groupby("Genre")["Popularity"].sum().sort_values(ascending=False).head(5)
a
plt.figure(figsize=(10,5))
sns.barplot(a, palette="deep")
plt.show()
# Out:
# C:\Users\soniv\AppData\Local\Temp\ipykernel_11800\1953716638.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(a, palette="deep")

# %% [raw]
# what movie got the lowest popularity what is genre

# %%
a= df[["Genre", "Popularity"]].sort_values(by="Popularity",ascending=True).head(10)
a
# Out:
#                                         Genre  Popularity
# 9826              War, Drama, Science Fiction      13.354
# 9825                    Music, Drama, History      13.354
# 9824                Mystery, Thriller, Horror      13.355
# 9823                                   Horror      13.356
# 9821  Science Fiction, Fantasy, Family, Music      13.357
# 9822                             Drama, Crime      13.357
# 9820                 Crime, Thriller, Mystery      13.358
# 9819                            Crime, Horror      13.359
# 9818                 Action, Adventure, Drama      13.359
# 9817                Romance, Animation, Drama      13.360

# %%
a =df.groupby("Genre")["Popularity"].sum().sort_values(ascending=True).head(5)
a
color = sns.color_palette("deep")
plt.pie(a,colors=color, labels=a.index,autopct="%1.1f%%")
plt.show()

# %% [raw]
# what movie got the lowest popularity what is Title

# %%
df[["Title", "Popularity"]].sort_values(by="Popularity",ascending=True).head(5)
# Out:
#                                      Title  Popularity
# 9826                               Threads      13.354
# 9825  The United States vs. Billie Holiday      13.354
# 9824                          The Offering      13.355
# 9823                      Violent Delights      13.356
# 9821                     The Little Prince      13.357

# %% [raw]
# which year has the most filmed moive

# %%
a = df.groupby("Year")["Title"].count().sort_values(ascending=False).head(10)
a
sns.barplot(a, palette="deep")
plt.show()
# Out:
# C:\Users\soniv\AppData\Local\Temp\ipykernel_11800\141950209.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(a, palette="deep")

# %%
df["Year"].hist()
# Out:
# <Axes: >

# %%
df
# Out:
#      Release_Date                                 Title  \
# 0      2021-12-15               Spider-Man: No Way Home
# 1      2022-03-01                            The Batman
# 2      2022-02-25                               No Exit
# 3      2021-11-24                               Encanto
# 4      2021-12-22                        The King's Man
# ...           ...                                   ...
# 9822   1973-10-15                              Badlands
# 9823   2020-10-01                      Violent Delights
# 9824   2016-05-06                          The Offering
# 9825   2021-03-31  The United States vs. Billie Holiday
# 9826   1984-09-23                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# ...

# %%
df["Genre"].value_counts()
# Out:
# Genre
# Drama                                            466
# Comedy                                           403
# Drama, Romance                                   248
# Horror                                           238
# Horror, Thriller                                 199
#                                                 ...
# Drama, Horror, Thriller, Science Fiction           1
# Action, Science Fiction, Animation, Adventure      1
# Comedy, Fantasy, Horror, Science Fiction           1
# Drama, Science Fiction, Animation                  1
# War, Drama, Science Fiction                        1
# Name: count, Length: 2337, dtype: int64

# %%
d = pd.read_csv("Netflix5_Cleaned (1).csv")
d
# Out:
#      Release_Date                                 Title  \
# 0      15-12-2021               Spider-Man: No Way Home
# 1      01-03-2022                            The Batman
# 2      25-02-2022                               No Exit
# 3      24-11-2021                               Encanto
# 4      22-12-2021                        The King's Man
# ...           ...                                   ...
# 9833   15-10-1973                              Badlands
# 9834   01-10-2020                      Violent Delights
# 9835   06-05-2016                          The Offering
# 9836   31-03-2021  The United States vs. Billie Holiday
# 9837   23-09-1984                               Threads
#
#                                                Overview  Popularity  \
# 0     Peter Parker is unmasked and no longer able to...    5083.954
# 1     In his second year of fighting crime, Batman u...    3827.658
# 2     Stranded at a rest stop in the mountains durin...    2618.087
# ...

# %%
d["Gender"].value_counts()
# Out:
# Gender
# Unknown    7347
# Female     1253
# Male       1238
# Name: count, dtype: int64
