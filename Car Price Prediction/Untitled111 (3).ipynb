# %% [raw]
# Problem
# Define the objective: Predict car prices based on various features.
#
# Identify dependent (target) and independent (feature) variables.

# %%
#Data preprocessing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Car-mpg- Dataset.csv")

# %%
df
# Out:
#       mpg  cyl   disp     hp    wt   acc  yr  origin  car_type  \
# 0    18.0    8  307.0  130.0  3504  12.0  70       1         0
# 1    15.0    8  350.0  165.0  3693  11.5  70       1         0
# 2    18.0    8  318.0  150.0  3436  11.0  70       1         0
# 3    16.0    8  304.0  150.0  3433  12.0  70       1         0
# 4    17.0    8  302.0  140.0  3449  10.5  70       1         0
# ..    ...  ...    ...    ...   ...   ...  ..     ...       ...
# 393  27.0    4  140.0   86.0  2790  15.6  82       1         1
# 394  44.0    4   97.0   52.0  2130  24.6  82       2         1
# 395  32.0    4  135.0   84.0  2295  11.6  82       1         1
# 396  28.0    4  120.0   79.0  2625  18.6  82       1         1
# 397  31.0    4  119.0   82.0  2720  19.4  82       1         1
#
#                       car_name
# 0    chevrolet chevelle malibu
# 1            buick skylark 320
# 2           plymouth satellite
# 3                amc rebel sst
# 4                  ford torino
# ...

# %%
df.describe().T
# Out:
#           count         mean         std     min       25%      50%       75%  \
# mpg       392.0    23.445918    7.805007     9.0    17.000    22.75    29.000
# cyl       392.0     5.471939    1.705783     3.0     4.000     4.00     8.000
# disp      392.0   194.411990  104.644004    68.0   105.000   151.00   275.750
# hp        392.0   104.469388   38.491160    46.0    75.000    93.50   126.000
# wt        392.0  2977.584184  849.402560  1613.0  2225.250  2803.50  3614.750
# acc       392.0    15.541327    2.758864     8.0    13.775    15.50    17.025
# yr        392.0    75.979592    3.683737    70.0    73.000    76.00    79.000
# origin    392.0     1.576531    0.805518     1.0     1.000     1.00     2.000
# car_type  392.0     0.525510    0.499987     0.0     0.000     1.00     1.000
#
#              max
# mpg         46.6
# cyl          8.0
# disp       455.0
# hp         230.0
# wt        5140.0
# acc         24.8
# yr          82.0
# origin       3.0
# car_type     1.0

# %%
df.isnull().sum()
# Out:
# mpg         0
# cyl         0
# disp        0
# hp          0
# wt          0
# acc         0
# yr          0
# origin      0
# car_type    0
# car_name    0
# dtype: int64

# %%
df.dtypes
# Out:
# mpg         float64
# cyl           int64
# disp        float64
# hp          float64
# wt            int64
# acc         float64
# yr            int64
# origin        int64
# car_type      int64
# dtype: object

# %%
df["hp"] = df["hp"].replace("?", "nan")

# %%
df.dropna(inplace=True)

# %%
df["hp"] = df["hp"].astype(float)

# %%
df = df.drop(columns=['car_name'], axis=1)
df
# Out:
#       mpg  cyl   disp     hp    wt   acc  yr  origin  car_type
# 0    18.0    8  307.0  130.0  3504  12.0  70       1         0
# 1    15.0    8  350.0  165.0  3693  11.5  70       1         0
# 2    18.0    8  318.0  150.0  3436  11.0  70       1         0
# 3    16.0    8  304.0  150.0  3433  12.0  70       1         0
# 4    17.0    8  302.0  140.0  3449  10.5  70       1         0
# ..    ...  ...    ...    ...   ...   ...  ..     ...       ...
# 393  27.0    4  140.0   86.0  2790  15.6  82       1         1
# 394  44.0    4   97.0   52.0  2130  24.6  82       2         1
# 395  32.0    4  135.0   84.0  2295  11.6  82       1         1
# 396  28.0    4  120.0   79.0  2625  18.6  82       1         1
# 397  31.0    4  119.0   82.0  2720  19.4  82       1         1
#
# [398 rows x 9 columns]

# %%
df["car_type"].value_counts()
# Out:
# car_type
# 1    211
# 0    187
# Name: count, dtype: int64

# %%
#Data visulization

# %%
#Univareint
#histplot
#boxplot

sns.histplot(df["mpg"], kde=True)
plt.show()

sns.boxplot(df["mpg"])
plt.show()

# %% [raw]
# Observation:
# 15 and 25 mpg (mileage per gallon )  are more car. after 30+ mpg is less car due to more mpg
# and right skewed graph
#
# litle outlier

# %%
sns.histplot(df["cyl"], kde=True)
plt.show()

sns.kdeplot(df["cyl"], shade=True)
plt.show()
# Out:
# C:\Users\soniv\AppData\Local\Temp\ipykernel_13164\3431898464.py:4: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["cyl"], shade=True)

# %% [raw]
# Observation:
# car in cylinder
# 4 cylinder in car is more  and 6 8 cylinder car is less  and 3, 5 cylinder car is few due to something is different

# %%
sns.histplot(df["disp"], kde=True)
plt.show()

sns.boxplot(df["disp"])
plt.show()

# %% [raw]
# Observation:
# Most car Displacement between 50 and 150
# less car displacement between 200 and 300
# very few car displacement 400+

# %%
sns.histplot(df["hp"], kde=True)
plt.show()
sns.boxplot(df["hp"])
plt.show()

# %% [raw]
# Observation:
# hp (horse power)  Car mostly hp berween 50 and 100  and 125 to 150 is less hp car but very few car hp is 175+

# %%
sns.histplot(df["wt"], kde=True)
plt.show()
sns.boxplot(df["wt"])
plt.show()

# %% [raw]
# observation:
# most car wt (weight) are 2000 between 3000
# less car wt are 3000 between 4000
# very few car wt 4500+

# %%
sns.histplot(df["acc"], kde=True)
plt.show()
sns.boxplot(df["acc"])
plt.show()

# %% [raw]
# Observation:
# mostly car acceleration between 12.5 and 17.5 after 20 car acceleration is very few also dec
# grah is normal distribution

# %%
sns.histplot(df["yr"], kde=True)
plt.show()
sns.boxplot(df["yr"])
plt.show()

# %% [raw]
# Observation:
# Most car is 70 and 76 82 year are sale
# less car sale is 72, 74, 78, 80

# %%
sns.histplot(df["origin"])
plt.show()
sns.boxplot(df["origin"])
plt.show()

# %% [raw]
# Observation:
# Most car in orgine 1
# less car is 3 orgine
# very few car is 2 orgine

# %%
#Bivarient
#lineplot
#barplot
#scatterplot
#heatmap

sns.kdeplot(df["cyl"], shade=True)
plt.show()

sns.kdeplot(df["origin"], shade=True)
plt.show()
# Out:
# C:\Users\soniv\AppData\Local\Temp\ipykernel_25432\3018733615.py:7: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["cyl"], shade=True)
# C:\Users\soniv\AppData\Local\Temp\ipykernel_25432\3018733615.py:10: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df["origin"], shade=True)

# %% [raw]
# obsevation:
# origin 1 is more car and origan 2 and 3 is less car
# data is Imbalanced and 1 cateogry is more data and 2 and 3 less data

# %%
sns.barplot(x=df["car_type"], y=df["hp"], data=df)
plt.show()

sns.barplot(x=df["car_type"], y=df["disp"], data=df)
plt.show()

# %% [raw]
# Observation:
# car type and hp  (horse power)
# car type 0  hp is approx 125
# car type 1 hp is approx 100
#
#
# car type and disp
# car type 0 is more displacement
# car type 1 is less displacent

# %%
#Data Visulization 
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap="coolwarm")
plt.show()

# %% [raw]
# observation
#
# #Highly Correlated Features (Above 0.9)
# cyl Cylinders & disp Displacement → 0.95  (More cylinders → More displacement)
#
# disp & hp (Horsepower) → 0.90  (More displacement → More horsepower)
#
# wt (Weight) & disp → 0.93  (Heavier cars tend to have bigger engines)
#
# hp & wt → 0.86  (More horsepower generally means a heavier car)
#
# #Strong Negative Correlations (Below -0.75)
#
# mpg (Miles Per Gallon) & wt (Weight) → -0.83
# (Heavier cars give lower mileage)
#
# mpg & hp (Horsepower) → -0.78
# (Higher horsepower leads to lower mileage)
#
# mpg & disp → -0.80
# (Bigger engines consume more fuel, reducing MPG)
#
# #Weak or No Correlation (Near 0)
#
# yr (Model Year) & hp (Horsepower) → -0.42
#
# acc (Acceleration) & wt → -0.42
#
# car_type & acc → 0.39

# %%
#Multi varient 
sns.pairplot(df)
plt.show()

# %%
#one hot encoding 
df = pd.get_dummies(df,columns=["origin"], dtype=int)
df
# Out:
#       mpg  cyl   disp     hp    wt   acc  yr  car_type  origin_1  origin_2  \
# 0    18.0    8  307.0  130.0  3504  12.0  70         0         1         0
# 1    15.0    8  350.0  165.0  3693  11.5  70         0         1         0
# 2    18.0    8  318.0  150.0  3436  11.0  70         0         1         0
# 3    16.0    8  304.0  150.0  3433  12.0  70         0         1         0
# 4    17.0    8  302.0  140.0  3449  10.5  70         0         1         0
# ..    ...  ...    ...    ...   ...   ...  ..       ...       ...       ...
# 393  27.0    4  140.0   86.0  2790  15.6  82         1         1         0
# 394  44.0    4   97.0   52.0  2130  24.6  82         1         0         1
# 395  32.0    4  135.0   84.0  2295  11.6  82         1         1         0
# 396  28.0    4  120.0   79.0  2625  18.6  82         1         1         0
# 397  31.0    4  119.0   82.0  2720  19.4  82         1         1         0
#
#      origin_3
# 0           0
# 1           0
# 2           0
# ...

# %%
#Feature Selection
x = df[["mpg","cyl" ,"disp","wt", "acc", "yr", "origin_1","origin_2","origin_3", "car_type"]]  #independent variable
y = df["hp"]  # Target variable

# %%
x.shape
# Out:
# (392, 10)

# %%
y.shape
# Out:
# (392,)

# %%
# Train Test Split data
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size=0.2, random_state=2)

# %%
X_train
# Out:
#       mpg  cyl   disp    wt   acc  yr  origin_1  origin_2  origin_3  car_type
# 202  17.5    6  258.0  3193  17.8  76         1         0         0         0
# 184  25.0    4  140.0  2572  14.9  76         1         0         0         1
# 3    16.0    8  304.0  3433  12.0  70         1         0         0         0
# 176  19.0    6  232.0  3211  17.0  75         1         0         0         0
# 261  18.1    6  258.0  3410  15.1  78         1         0         0         0
# ..    ...  ...    ...   ...   ...  ..       ...       ...       ...       ...
# 301  34.2    4  105.0  2200  13.2  79         1         0         0         1
# 22   25.0    4  104.0  2375  17.5  70         0         1         0         1
# 73   13.0    8  307.0  4098  14.0  72         1         0         0         0
# 15   22.0    6  198.0  2833  15.5  70         1         0         0         0
# 170  23.0    4  140.0  2592  18.5  75         1         0         0         1
#
# [313 rows x 10 columns]

# %%
Y_test.head(9)
# Out:
# 56      70.0
# 71      97.0
# 315     90.0
# 181     53.0
# 309     76.0
# 326     48.0
# 386    110.0
# 109     72.0
# 201    110.0
# Name: hp, dtype: float64

# %%
Y_test.shape
# Out:
# (79,)

# %%
y_pred.shape
# Out:
# (1, 1)

# %%
print(X_train.shape, X_test.shape, Y_train.shape, Y_test.shape)
# Out:
# (313, 10) (79, 10) (313,) (79,)

# %%
#Model Selection
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test.iloc[[2]])

# %%
y_pred = y_pred.reshape(-1,1)
y_pred
# Out:
# array([[78.13885694]])

# %%
#metric Efficency Model Evaluation

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_pred = lr.predict(X_test)  # Ensure predictions for full test set
                                    
print("MAE:", mean_absolute_error(Y_test, y_pred))
print("MSE:", mean_squared_error(Y_test, y_pred))
print("R2 Score:", r2_score(Y_test, y_pred)*100)
# Out:
# MAE: 9.654084084906046
# MSE: 178.2811159040918
# R2 Score: 88.35707455560531

# %%
lr.intercept_
# Out:
# 111.49494307611143

# %%
lr.coef_
# Out:
# array([-0.60288842,  1.64422364,  0.16733391,  0.01529848, -4.28945148,
#        -0.25435003, -4.54505611,  0.02815421,  4.5169019 , 14.60748428])
